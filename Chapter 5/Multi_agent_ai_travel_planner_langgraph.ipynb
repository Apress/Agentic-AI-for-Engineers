# %%
import streamlit as st
# !streamlit run multi_agent_ai_travel_planner_langgraph.py --server.headless true
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://10.0.0.124:8501
#   External URL: http://71.193.64.148:8501
#
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Travel Research Specialist                                           │
# │                                                                              │
# │  Task: You MUST perform a factual travel research operation                  │
# │  for the destination: New York City.                                         │
# │                                                                              │
# │  REQUIREMENTS:                                                               │
# │  - Search specifically for "New York City top attractions",                  │
# ...
