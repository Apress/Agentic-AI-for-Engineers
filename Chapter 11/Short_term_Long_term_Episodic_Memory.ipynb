# %% [markdown]
# ## Short term- Long Term- Episodic Memory Example

# %%
import os
import shutil
from typing import TypedDict, Annotated, List
from datetime import datetime
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage, BaseMessage
from langchain_core.documents import Document

# ✅ FIXED: Use standard pydantic instead of langchain_core wrapper
from pydantic import BaseModel, Field 

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.checkpoint.memory import MemorySaver

load_dotenv()


# ==============================================================================
# 1. MEMORY STORAGE SETUP
# ==============================================================================

# --- A. Episodic Memory (Vector DB) ---
# We use a local vector store to save "Events"
embedding_function = OpenAIEmbeddings()
PERSIST_DIR = "./chroma_memory_db"

# Cleanup previous run for fresh start (Optional)
if os.path.exists(PERSIST_DIR):
    shutil.rmtree(PERSIST_DIR)

vector_store = Chroma(
    collection_name="episodic_memory",
    embedding_function=embedding_function,
    persist_directory=PERSIST_DIR
)

# --- B. Long-Term Memory (Structured Profile) ---
# In production, this would be a User Table in Postgres
user_profile_db = {
    "user_123": {
        "name": "Unknown",
        "core_goals": [],
        "hobbies": []
    }
}

# ==============================================================================
# 2. STATE & SCHEMA DEFINITIONS
# ==============================================================================

class UserProfileUpdate(BaseModel):
    """Schema for extracting LTM updates from conversation"""
    name: str = Field(description="The user's name if mentioned")
    new_goals: List[str] = Field(description="Any new goals the user mentioned")
    new_hobbies: List[str] = Field(description="Any new hobbies mentioned")

class AgentState(TypedDict):
    messages: Annotated[list, add_messages] # <--- STM (Short Term)
    user_id: str
    episodic_context: str  # <--- Relevant past events fetched from Vector DB
    user_profile: str      # <--- Structured facts fetched from JSON DB

# ==============================================================================
# 3. GRAPH NODES (The Brain)
# ==============================================================================

# --- NODE 1: RECALL (Fetch LTM & Episodic) ---
def recall_memory_node(state: AgentState):
    user_id = state["user_id"]
    latest_query = state["messages"][-1].content
    
    # 1. Fetch LTM (Profile)
    profile = user_profile_db.get(user_id, {})
    profile_str = f"Name: {profile.get('name')}, Goals: {profile.get('core_goals')}"
    
    # 2. Fetch Episodic (Vector Search)
    # Search for similar past conversations
    docs = vector_store.similarity_search(latest_query, k=2)
    episodic_str = "\n".join([d.page_content for d in docs]) if docs else "No relevant past memories."
    
    print(f"🧠 RECALLING:\n  - Profile: {profile_str}\n  - Past Events: {episodic_str[:50]}...")
    
    return {
        "user_profile": profile_str,
        "episodic_context": episodic_str
    }

# --- NODE 2: GENERATE (The Response) ---
def generate_node(state: AgentState):
    llm = ChatOpenAI(model="gpt-4o-mini")
    
    # Inject ALL memories into the system prompt
    system_prompt = (
        f"You are a Life Coach. \n"
        f"--- LONG TERM INFO ---\n{state['user_profile']}\n"
        f"--- PAST RELEVANT MEMORIES ---\n{state['episodic_context']}\n"
        f"--------------------------\n"
        f"Use this context to give personalized advice."
    )
    
    messages = [SystemMessage(content=system_prompt)] + state["messages"]
    response = llm.invoke(messages)
    
    return {"messages": [response]}

# --- NODE 3: CONSOLIDATE (Save New Memories) ---
def save_memory_node(state: AgentState):
    user_id = state["user_id"]
    last_user_msg = state["messages"][-2].content # The user's input
    last_ai_msg = state["messages"][-1].content   # The AI's response
    
    # 1. Update Episodic Memory (Vector Store)
    # We save the interaction so we can find it later
    memory_text = f"User said: {last_user_msg} | AI advised: {last_ai_msg}"
    current_time = datetime.now().strftime("%Y-%m-%d %H:%M")
    
    vector_store.add_documents([
        Document(page_content=memory_text, metadata={"user_id": user_id, "timestamp": current_time})
    ])
    
    # 2. Update Long Term Memory (Profile Extraction)
    # We ask a "quiet" LLM instance to extract facts
    extractor = ChatOpenAI(model="gpt-4o-mini").with_structured_output(UserProfileUpdate)
    
    extraction_prompt = f"Analyze this conversation and update the user profile: {last_user_msg}"
    update = extractor.invoke(extraction_prompt)
    
    # Update the "Database"
    current_profile = user_profile_db[user_id]
    if update.name != "Unknown":
        current_profile["name"] = update.name
    if update.new_goals:
        current_profile["core_goals"].extend(update.new_goals)
    
    print(f"💾 SAVED: Added to vector DB & Updated Profile: {current_profile}")
    return {} # No state update needed, just side effects

# ==============================================================================
# 4. BUILDING THE GRAPH
# ==============================================================================

builder = StateGraph(AgentState)

builder.add_node("recall", recall_memory_node)
builder.add_node("generate", generate_node)
builder.add_node("save", save_memory_node)

# Flow: Start -> Recall -> Generate -> Save -> End
builder.add_edge(START, "recall")
builder.add_edge("recall", "generate")
builder.add_edge("generate", "save")
builder.add_edge("save", END)

memory = MemorySaver() # This is the STM checkpointer
graph = builder.compile(checkpointer=memory)

# ==============================================================================
# 5. SIMULATION
# ==============================================================================

def chat(message, thread_id):
    config = {"configurable": {"thread_id": thread_id}}
    print(f"\n💬 User: {message}")
    
    # We initialize the state with user_id for DB lookups
    initial_state = {
        "messages": [HumanMessage(content=message)],
        "user_id": "user_123" 
    }
    
    # Run the graph
    events = graph.invoke(initial_state, config)
    print(f"🤖 Coach: {events['messages'][-1].content}")

if __name__ == "__main__":
    t_id = "session_1"
    
    # Turn 1: Introduction (Sets LTM)
    chat("Hi, my name is Alex. I want to train for a marathon.", t_id)
    
    # Turn 2: Specific Event (Sets Episodic)
    chat("I went for a run today but my knee hurt really bad.", t_id)
    
    print("\n--- 🕒 TIME PASSES (New Session) ---\n")
    t_id_2 = "session_2" # New Thread ID = STM is wiped!
    
    # Turn 3: Retrieval (Tests LTM + Episodic)
    # Even though STM is gone, it should know my name (LTM) and my knee issue (Episodic)
    chat("I'm thinking of going for a sprint today. What do you think?", t_id_2)
# Out:
# 💬 User: Hi, my name is Alex. I want to train for a marathon.
# 🧠 RECALLING:
#   - Profile: Name: Unknown, Goals: []
#   - Past Events: No relevant past memories....
# 💾 SAVED: Added to vector DB & Updated Profile: {'name': 'Alex', 'core_goals': ['train for a marathon'], 'hobbies': []}
# 🤖 Coach: Hi Alex! It’s great to hear that you want to train for a marathon! That’s an exciting goal and a fantastic challenge. Let’s break things down to help you get started.
#
# 1. **Set Clear Goals**: Define what you want to achieve. Do you have a specific marathon in mind? Setting a target date can help you create a structured training plan.
#
# 2. **Create a Training Plan**: A typical marathon training plan ranges from 16 to 20 weeks and includes a mix of long runs, easy runs, speed work, and rest days. Find a plan that suits your current fitness level, and adjust if necessary.
#
# 3. **Build Your Base**: If you’re new to running, start by building your base mileage. Aim to run a few times a week, gradually increasing your distance. Consistency is key!
#
# 4. **Listen to Your Body**: Pay attention to how your body feels during training. If you experience pain, it may be wise to incorporate rest or cross-training activities (like cycling or swimming) to prevent injuries.
#
# 5. **Nutrition and Hydration**: Proper fueling is essential for your training. Focus on a balanced diet rich in whole foods and stay hydrated. Consider experimenting with nutrition strategies for long runs.
#
# 6. **Join a Running Group**: Connecting with others can provide motivation and support. Look for local running clubs or online communities where you can share your progress and find training partners.
#
# 7. **Mental Preparation**: Marathon training is as much mental as it is physical. Practice positive self-talk and visualization exercises to build your mental resilience.
#
# 8. **Rest and Recovery**: Don’t overlook the importance of rest days and recovery. Adequate sleep, stretching, and recovery workouts will help you avoid burnout.
#
# 9. **Celebrate Small Wins**: Training for a marathon is a long journey. Celebrate your milestones along the way to keep your spirits high.
#
# If you have any specific questions or need help with a training plan, feel free to ask! I’m here to support you.
#
# 💬 User: I went for a run today but my knee hurt really bad.
# 🧠 RECALLING:
#   - Profile: Name: Alex, Goals: ['train for a marathon']
#   - Past Events: User said: Hi, my name is Alex. I want to train fo...
# 💾 SAVED: Added to vector DB & Updated Profile: {'name': '', 'core_goals': ['train for a marathon', 'Improve knee strength and recovery after running'], 'hobbies': []}
# 🤖 Coach: I'm sorry to hear that your knee is hurting, Alex. It's important to listen to your body, especially when you're training for a marathon. Here are some steps you can take:
#
# 1. **Rest**: Give your knee some time to recover. Avoid running or any high-impact activities until the pain subsides.
#
# 2. **Ice**: Apply ice to the affected area for 15-20 minutes several times a day to reduce swelling and inflammation.
#
# 3. **Elevation**: Try to keep your leg elevated to help minimize swelling.
#
# 4. **Evaluate**: Think about potential causes of the pain. Did you change your running shoes, training surfaces, or increase your mileage suddenly? Sometimes minor adjustments can lead to discomfort.
#
# 5. **Cross-Training**: Consider low-impact exercises like swimming or cycling to maintain your fitness while allowing your knee to heal.
#
# 6. **Stretching and Strengthening**: Once the pain subsides, incorporate gentle stretching and strengthening exercises for your legs and core. This can help prevent future injuries.
#
# 7. **Consult a Professional**: If the pain persists or worsens, it may be wise to consult a healthcare professional or a physical therapist. They can provide a proper diagnosis and recommend specific exercises or treatments.
#
# 8. **Gradual Return**: When you're ready to get back to running, do so gradually. Start with shorter, easy runs and see how your knee responds before increasing intensity or distance.
#
# Your health is the top priority, so be sure to take care of yourself! If you have any further questions or need additional support, I'm here to help.
#
# --- 🕒 TIME PASSES (New Session) ---
#
#
# 💬 User: I'm thinking of going for a sprint today. What do you think?
# 🧠 RECALLING:
#   - Profile: Name: , Goals: ['train for a marathon', 'Improve knee strength and recovery after running']
#   - Past Events: User said: Hi, my name is Alex. I want to train fo...
# 💾 SAVED: Added to vector DB & Updated Profile: {'name': '', 'core_goals': ['train for a marathon', 'Improve knee strength and recovery after running'], 'hobbies': []}
# 🤖 Coach: It's great that you're considering a sprint workout, but since you've mentioned experiencing knee pain after your last run, I would recommend being cautious. Here are a few things to consider:
#
# 1. **Listen to Your Body**: If your knee is still sore or if you've recently felt discomfort, it's best to hold off on sprinting. Sprinting can put additional strain on your knees, especially if they aren't fully healed.
#
# 2. **Warm-Up**: If you decide to go ahead with it, make sure to warm up thoroughly. Dynamic stretches and light jogging can help prepare your muscles and joints for the intensity of sprinting.
#
# 3. **Alternative Workout**: If you're uncertain about your knee's readiness, consider low-impact alternatives such as cycling, swimming, or even a gentle jog. These options can help maintain your fitness without putting extra stress on your knees.
#
# 4. **Focus on Recovery**: If your knee is still not feeling 100%, it might be a good day for rest, ice, and elevation instead. Recovery is crucial, especially as you prepare for your marathon.
#
# 5. **Consult a Professional**: If your knee pain persists or you feel uneasy about it, speaking to a healthcare professional or a physical therapist could provide valuable insights and guidance.
#
# Your long-term goal of training for a marathon is important, so taking the time to ensure your body is ready will pay off in the long run. Let me know if you need more advice or if there’s anything specific you’d like to discuss!

# %%
# Analysis: What just happened?
# If you run this code, look closely at Turn 3.

# STM (Short Term) is wiped: session_2 is a new thread. The bot technically doesn't know what you just said 5 seconds ago in session_1.

# LTM (Long Term) kicks in: The recall_memory_node looks up user_123 in the dictionary. It sees Name: Alex and Goal: Marathon.

# Episodic Memory kicks in: The recall_memory_node vector searches for "sprint" or "run". It finds the vector chunk: "User said: I went for a run today but my knee hurt really bad."

# The Result: The bot will say:

# "Hi Alex! Since you're training for a marathon, that's great, but be careful because you mentioned your knee hurt last time."

# Key Takeaway
# You have successfully decoupled the three memory types:

# STM lives in MemorySaver (RAM/Checkpointer).

# LTM lives in user_profile_db (Structure).

# Episodic lives in vector_store (Semantic Search).
