# %%
# !streamlit run Stateful_travel_agent.py --server.headless true
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://10.0.0.126:8502
#   External URL: http://75.72.218.116:8502
#
# 🔄 Initializing Graph and Memory...
# /Users/dhivyanaga/Library/CloudStorage/GoogleDrive-dnagasubramanian@gmail.com/My Drive/Chap11/Stateful_travel_agent.py:32: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)
# 2026-01-16 21:09:55.666 Examining the path of torch.classes raised: Tried to instantiate class '__path__._path', but it does not exist! Ensure that it is registered via torch::class_
# ...

# %%
# !streamlit run Short_term_long_term_Episodic_memory_LifeCoach_withUI.py --server.headless true
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://10.0.0.126:8502
#   External URL: http://75.72.218.116:8502
#
#
# ...
# 🤖 MEMORY-ENABLED LIFE COACH CHATBOT
# ...
#
# I'm your personal Life Coach with memory! I remember:
# - Your name and personal details
# - Your goals and interests
# - Our past conversations
#
# Commands:
#   /profile  - See what I remember about you
#   /new      - Start new session (keeps long-term memory)
#   /clear    - Clear all memory (fresh start)
#   /help     - Show this message
#   /quit     - Exit
#
# Let's chat! Tell me about yourself or what's on your mind.
#
# ...
#
# Enter your name (or press Enter for 'Guest'):
# ...
# 🤖 MEMORY-ENABLED LIFE COACH CHATBOT
# ...
#
# I'm your personal Life Coach with memory! I remember:
# - Your name and personal details
# - Your goals and interests
# - Our past conversations
#
# Commands:
#   /profile  - See what I remember about you
# ...
